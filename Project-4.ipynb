# %%
import pymongo
from bson.json_util import dumps, ObjectId
import json
import pandas as pd

# %%
# Connect to MongoDB
client = pymongo.MongoClient('mongodb://localhost:27017/')
db = 'climate'
collection = 'climate'

# %%
# Connect to MongoDB
db = client[db]
collection = db[collection]

# %%
# Retrieve the data from the collection
data = list(collection.find())

# %%
# Convert the data to JSON
json_data = dumps(data)

# %%
# Remove the _id field from json_data
json_data = json.loads(json_data)
for i in json_data:
    i.pop('_id', None)

# %%
# Load the data.json file into a pandas dataframe
df = pd.read_json('data.json')
df.head()
# Out:
#                                              alabama  \
# 0  {'precip': {'2010': 2.87, '2011': 3.79, '2012'...
#
#                                               alaska  \
# 0  {'precip': {'2010': 6.5, '2011': 6.39, '2012':...
#
#                                              arizona  \
# 0  {'precip': {'2010': 6.74, '2011': 6.98, '2012'...
#
#                                             arkansas  \
# 0  {'precip': {'2010': 2.44, '2011': 2.14, '2012'...
#
#                                           california  \
# 0  {'precip': {'2010': 0.8200000000000001, '2011'...
#
#                                             colorado  \
# 0  {'precip': {'2010': 1, '2011': 1.2, '2012': 0....
#
#                                          connecticut  \
# 0  {'precip': {'2010': 3.75, '2011': 4.16, '2012'...
#
#                                             delaware  \
# 0  {'precip': {'2010': 2.5300000000000002, '2011'...
#
#                                              florida  \
# ...

# %%
# Create an empty dataframe to store the transformed data
df_transformed = pd.DataFrame(columns=['State', 'Year', 'Precipitation', 'Max Temp', 'Min Temp', 'Wind Speed'])

# %%
# Iterate over each column (state)
for state in df.columns:
    # Extract the nested dictionary for the state
    state_data = df[state].values[0]
    # Get the precipitation data
    precip_data = state_data['precip']
    # Iterate over each year in the precipitation data
    for year, precip in precip_data.items():
        # Append the state, year, and precipitation to the transformed dataframe
        df_transformed = df_transformed.append({
            'State': state,
            'Year': year,
            'Precipitation': precip
        }, ignore_index=True)

# Display the transformed dataframe
df_transformed.head()
# Out:
# C:\Users\mybub\AppData\Local\Temp\ipykernel_2836\2115789966.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_transformed = df_transformed.append({
# C:\Users\mybub\AppData\Local\Temp\ipykernel_2836\2115789966.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_transformed = df_transformed.append({
# C:\Users\mybub\AppData\Local\Temp\ipykernel_2836\2115789966.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_transformed = df_transformed.append({
# C:\Users\mybub\AppData\Local\Temp\ipykernel_2836\2115789966.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_transformed = df_transformed.append({
# ...

# %%
# Iterate over each column (state)
for state in df.columns:
    # Extract the nested dictionary for the state
    state_data = df[state].values[0]
    # Get the additional data
    max_temp_data = state_data.get('max_temp', {})
    min_temp_data = state_data.get('min_temp', {})
    wind_speed_data = state_data.get('wind_speed', {})
    # Iterate over each year in the data and update the dataframe
    for year in max_temp_data.keys():
        df_transformed.loc[(df_transformed['State'] == state) & (df_transformed['Year'] == year), 'Max Temp'] = max_temp_data[year]
    for year in min_temp_data.keys():
        df_transformed.loc[(df_transformed['State'] == state) & (df_transformed['Year'] == year), 'Min Temp'] = min_temp_data[year]
    for year in wind_speed_data.keys():
        df_transformed.loc[(df_transformed['State'] == state) & (df_transformed['Year'] == year), 'Wind Speed'] = wind_speed_data[year]

# Display the transformed dataframe
df_transformed.head()
# Out:
#      State  Year  Precipitation Max Temp Min Temp Wind Speed
# 0  alabama  2010           2.87     12.6     6.22      15.85
# 1  alabama  2011           3.79    12.25     5.95       15.7
# 2  alabama  2012           2.74    13.73     7.22      15.64
# 3  alabama  2013           3.29    11.92     5.39      16.27
# 4  alabama  2014           3.11    11.08     4.33      16.34
